# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.
#
# Matplotlib is a library which is used to display the statistic and visualization the data
#
# #plot #scatter #subplot #barplot #boxplot

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
#
# Scatter plot : it is a chart that shows the relationship between two variable

# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x,y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("scater plot")
# Out:
# Text(0.5, 1.0, 'scater plot')

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %%
x1 = np.array([0, 1, 2, 3, 4, 5]) 
y1 = np.array([0, 100, 200, 300, 400, 500])

# %%
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])

# %%
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])

# %%
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])

# %%
fig, axs = plt.subplots(2,2)
axs[0,0].plot(x1,y1)
axs[0,1].plot(x2,y2)
axs[1,0].plot(x3,y3)
axs[1,1].plot(x4,y4)

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# Barplot :Is a common type of plot,which is used a relationship between numerical and categorical data

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# Boxplot : Its a visualize chart plot, if an one or more than set or data can visualize than we can use boxplot

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
data =[box1,box2]
fig, a=plt.subplots()
a.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x23dc2a976d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x23dc2aa4b90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x23dc2a67050>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x23dc2aa5a10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x23dc2aa6350>,
# ...
#  'means': []}
